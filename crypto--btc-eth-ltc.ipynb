# %%
# !pip install yfinance

# Install required libraries
# !pip install numpy pandas matplotlib scikit-learn tensorflow

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Define the tickers for Bitcoin, Ethereum, and Litecoin
cryptos = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Define the start and end date for the data
start_date = '2019-01-01'
end_date = '2024-01-01'

# Create an empty dictionary to store the data
crypto_data = {}

# Download and store data in the dictionary
for ticker in cryptos:
    crypto_data[ticker] = yf.download(ticker, start=start_date, end=end_date)

    # Display the first few rows of each dataframe
    print(f"Showing data for {ticker}:")
    display(crypto_data[ticker].head())

from sklearn.preprocessing import MinMaxScaler

# Define the tickers for Bitcoin, Ethereum, and Litecoin
cryptos = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Assuming we're working with Bitcoin data for this example
btc_data = crypto_data['BTC-USD']

# 1. Handle missing data
# For simplicity, we'll fill missing values with the last available value
btc_data.fillna(method='ffill', inplace=True)

# 2. Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_btc = scaler.fit_transform(btc_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

# 3. Convert the data into a time series format
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1]) # Assuming close price is the target variable
    return np.array(X), np.array(Y)

# Define look_back period
look_back = 60 # for example, using past 60 days to predict the next day

# Split into features (X) and target (Y)
X_btc, Y_btc = create_dataset(scaled_data_btc, look_back)

# Reshape features into the format expected by LSTM (samples, time steps, features)
X_btc = np.reshape(X_btc, (X_btc.shape[0], look_back, X_btc.shape[2]))

# Split into train and test sets
split_percent = 0.80
split = int(split_percent*len(X_btc))

X_train_btc = X_btc[:split]
Y_train_btc = Y_btc[:split]
X_test_btc = X_btc[split:]
Y_test_btc = Y_btc[split:]

print("Data preprocessed and ready for model training.")

# !pip install tensorflow

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
lstm_model.add(LSTM(units=100))
lstm_model.add(Dense(1))

lstm_model.compile(optimizer='adam', loss='mean_squared_error')

from tensorflow.keras.layers import GRU

# Define the GRU model
gru_model = Sequential()
gru_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
gru_model.add(GRU(units=100))
gru_model.add(Dense(1))

gru_model.compile(optimizer='adam', loss='mean_squared_error')

from tensorflow.keras.layers import Bidirectional

# Define the BiLSTM model
bilstm_model = Sequential()
bilstm_model.add(Bidirectional(LSTM(units=100, return_sequences=True), input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))
bilstm_model.add(Bidirectional(LSTM(units=100)))
bilstm_model.add(Dense(1))

bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
lstm_history = lstm_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)

# Train the GRU model
gru_history = gru_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)

# Train the BiLSTM model
bilstm_history = bilstm_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)

# Evaluate the LSTM model
lstm_scores = lstm_model.evaluate(X_test_btc, Y_test_btc, verbose=0)
print('LSTM Test loss:', lstm_scores)

# Evaluate the GRU model
gru_scores = gru_model.evaluate(X_test_btc, Y_test_btc, verbose=0)
print('GRU Test loss:', gru_scores)

# Evaluate the BiLSTM model
bilstm_scores = bilstm_model.evaluate(X_test_btc, Y_test_btc, verbose=0)
print('BiLSTM Test loss:', bilstm_scores)

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
plt.plot(lstm_history.history['loss'], label='LSTM training Loss')
plt.plot(lstm_history.history['val_loss'], label='LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,2)
plt.plot(gru_history.history['loss'], label='GRU training Loss')
plt.plot(gru_history.history['val_loss'], label='GRU Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,3)
plt.plot(bilstm_history.history['loss'], label='Bi-LSTM training Loss')
plt.plot(bilstm_history.history['val_loss'], label='Bi-LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_predictions = lstm_model.predict(X_test_btc)
gru_predictions = gru_model.predict(X_test_btc)
bilstm_predictions = bilstm_model.predict(X_test_btc)

# Calculate MSE and MAE for LSTM
lstm_mse = mean_squared_error(Y_test_btc, lstm_predictions)
lstm_mae = mean_absolute_error(Y_test_btc, lstm_predictions)

# Calculate MSE and MAE for GRU
gru_mse = mean_squared_error(Y_test_btc, gru_predictions)
gru_mae = mean_absolute_error(Y_test_btc, gru_predictions)

# Calculate MSE and MAE for BiLSTM
bilstm_mse = mean_squared_error(Y_test_btc, bilstm_predictions)
bilstm_mae = mean_absolute_error(Y_test_btc, bilstm_predictions)

# Print the scores
print(f'LSTM MSE: {lstm_mse}, MAE: {lstm_mae}')
print(f'GRU MSE: {gru_mse}, MAE: {gru_mae}')
print(f'BiLSTM MSE: {bilstm_mse}, MAE: {bilstm_mae}')

from tensorflow.keras.optimizers import Adam

# Tune LSTM hyperparameters
tuned_lstm_model = Sequential()
tuned_lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_btc.shape[1], X_train_btc.shape[2])))

tuned_lstm_model.add(LSTM(units=100))
tuned_lstm_model.add(Dense(1))

# Adjust learning rate
optimizer = Adam(learning_rate=0.001)
tuned_lstm_model.compile(optimizer=optimizer, loss='mean_squared_error')

# Retrain with new hyperparameters
tuned_lstm_history = tuned_lstm_model.fit(X_train_btc, Y_train_btc, epochs=100, batch_size=32, validation_data=(X_test_btc, Y_test_btc), verbose=1)

# Plot actual vs. predicted prices for the best-performing model (example with LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_btc, label='Actual Prices')
plt.plot(lstm_predictions, label='Predicted Prices')
plt.title('For BTC Comparison of Actual and LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape


# Assuming Y_test, lstm_predictions, gru_predictions, and bilstm_predictions are already defined

# Calculate RMSE for each model
lstm_rmse = calculate_rmse(Y_test_btc, lstm_predictions.flatten())
gru_rmse = calculate_rmse(Y_test_btc, gru_predictions.flatten())
bilstm_rmse = calculate_rmse(Y_test_btc, bilstm_predictions.flatten())

# Calculate MAPE for each model
lstm_mape = calculate_mape(Y_test_btc, lstm_predictions.flatten())
gru_mape = calculate_mape(Y_test_btc, gru_predictions.flatten())
bilstm_mape = calculate_mape(Y_test_btc, bilstm_predictions.flatten())

# Print RMSE and MAPE for each model
print(f'LSTM RMSE: {lstm_rmse:.3f}, MAPE: {lstm_mape:.2f}%')
print(f'GRU RMSE: {gru_rmse:.3f}, MAPE: {gru_mape:.2f}%')
print(f'BiLSTM RMSE: {bilstm_rmse:.3f}, MAPE: {bilstm_mape:.2f}%')

# Plot actual vs. predicted prices for the best-performing model (example with GRU)
plt.figure(figsize=(10,6))
plt.plot(Y_test_btc, label='Actual Prices')
plt.plot(gru_predictions, label='Predicted Prices')
plt.title('For BTC Comparison of Actual and GRU-Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

# Plot actual vs. predicted prices for the best-performing model (example with Bi-LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_btc, label='Actual Prices')
plt.plot(bilstm_predictions, label='Predicted Prices')
plt.title('For BTC Comparison of Actual and Bi-LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()


#now for Ethereum coins all the codes:

from sklearn.preprocessing import MinMaxScaler

# Define the tickers for Bitcoin, Ethereum, and Litecoin
cryptos = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Assuming we're working with Bitcoin data for this example
eth_data = crypto_data['ETH-USD']

# 1. Handle missing data
# For simplicity, we'll fill missing values with the last available value
eth_data.fillna(method='ffill', inplace=True)

# 2. Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_eth = scaler.fit_transform(eth_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

# 3. Convert the data into a time series format
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1]) # Assuming close price is the target variable
    return np.array(X), np.array(Y)

# Define look_back period
look_back = 60 # for example, using past 60 days to predict the next day

# Split into features (X) and target (Y)
X_eth, Y_eth = create_dataset(scaled_data_eth, look_back)

# Reshape features into the format expected by LSTM (samples, time steps, features)
X_eth = np.reshape(X_eth, (X_eth.shape[0], look_back, X_eth.shape[2]))

# Split into train and test sets
split_percent = 0.80
split = int(split_percent*len(X_eth))

X_train_eth = X_eth[:split]
Y_train_eth = Y_eth[:split]
X_test_eth = X_eth[split:]
Y_test_eth = Y_eth[split:]

print("Data preprocessed and ready for model training.")


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
lstm_model.add(LSTM(units=100))
lstm_model.add(Dense(1))

lstm_model.compile(optimizer='adam', loss='mean_squared_error')


from tensorflow.keras.layers import GRU

# Define the GRU model
gru_model = Sequential()
gru_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
gru_model.add(GRU(units=100))
gru_model.add(Dense(1))

gru_model.compile(optimizer='adam', loss='mean_squared_error')


from tensorflow.keras.layers import Bidirectional

# Define the BiLSTM model
bilstm_model = Sequential()
bilstm_model.add(Bidirectional(LSTM(units=100, return_sequences=True), input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
bilstm_model.add(Bidirectional(LSTM(units=100)))
bilstm_model.add(Dense(1))

bilstm_model.compile(optimizer='adam', loss='mean_squared_error')

# Train the LSTM model
lstm_history = lstm_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)

# Train the GRU model
gru_history = gru_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)

# Train the BiLSTM model
bilstm_history = bilstm_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)

# Evaluate the LSTM model
lstm_scores = lstm_model.evaluate(X_test_eth, Y_test_eth, verbose=0)
print('LSTM Test loss:', lstm_scores)

# Evaluate the GRU model
gru_scores = gru_model.evaluate(X_test_eth, Y_test_eth, verbose=0)
print('GRU Test loss:', gru_scores)

# Evaluate the BiLSTM model
bilstm_scores = bilstm_model.evaluate(X_test_eth, Y_test_eth, verbose=0)
print('BiLSTM Test loss:', bilstm_scores)


plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
plt.plot(lstm_history.history['loss'], label='LSTM training Loss')
plt.plot(lstm_history.history['val_loss'], label='LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,2)
plt.plot(gru_history.history['loss'], label='GRU training Loss')
plt.plot(gru_history.history['val_loss'], label='GRU Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,3)
plt.plot(bilstm_history.history['loss'], label='Bi-LSTM training Loss')
plt.plot(bilstm_history.history['val_loss'], label='Bi-LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_predictions = lstm_model.predict(X_test_eth)
gru_predictions = gru_model.predict(X_test_eth)
bilstm_predictions = bilstm_model.predict(X_test_eth)

# Calculate MSE and MAE for LSTM
lstm_mse = mean_squared_error(Y_test_eth, lstm_predictions)
lstm_mae = mean_absolute_error(Y_test_eth, lstm_predictions)

# Calculate MSE and MAE for GRU
gru_mse = mean_squared_error(Y_test_eth, gru_predictions)
gru_mae = mean_absolute_error(Y_test_eth, gru_predictions)

# Calculate MSE and MAE for BiLSTM
bilstm_mse = mean_squared_error(Y_test_eth, bilstm_predictions)
bilstm_mae = mean_absolute_error(Y_test_eth, bilstm_predictions)

# Print the scores
print(f'LSTM MSE: {lstm_mse}, MAE: {lstm_mae}')
print(f'GRU MSE: {gru_mse}, MAE: {gru_mae}')
print(f'BiLSTM MSE: {bilstm_mse}, MAE: {bilstm_mae}')

from tensorflow.keras.optimizers import Adam

# Tune LSTM hyperparameters
tuned_lstm_model = Sequential()
tuned_lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_eth.shape[1], X_train_eth.shape[2])))
tuned_lstm_model.add(LSTM(units=100))
tuned_lstm_model.add(Dense(1))

# Adjust learning rate
optimizer = Adam(learning_rate=0.001)
tuned_lstm_model.compile(optimizer=optimizer, loss='mean_squared_error')

# Retrain with new hyperparameters
tuned_lstm_history = tuned_lstm_model.fit(X_train_eth, Y_train_eth, epochs=100, batch_size=32, validation_data=(X_test_eth, Y_test_eth), verbose=1)

# Plot actual vs. predicted prices for the best-performing model (example with LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_eth, label='Actual Prices')
plt.plot(lstm_predictions, label='Predicted Prices')
plt.title('For ETH Comparison of Actual and LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

# Plot actual vs. predicted prices for the best-performing model (example with GRU)
plt.figure(figsize=(10,6))
plt.plot(Y_test_eth, label='Actual Prices')
plt.plot(gru_predictions, label='Predicted Prices')
plt.title('For ETH Comparison of Actual and GRU-Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

# Plot actual vs. predicted prices for the best-performing model (example with Bi-LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_eth, label='Actual Prices')
plt.plot(bilstm_predictions, label='Predicted Prices')
plt.title('For ETH Comparison of Actual and Bi-LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape

# Assuming Y_test, lstm_predictions, gru_predictions, and bilstm_predictions are already defined

# Calculate RMSE for each model
lstm_rmse = calculate_rmse(Y_test_eth, lstm_predictions.flatten())
gru_rmse = calculate_rmse(Y_test_eth, gru_predictions.flatten())
bilstm_rmse = calculate_rmse(Y_test_eth, bilstm_predictions.flatten())

# Calculate MAPE for each model
lstm_mape = calculate_mape(Y_test_eth, lstm_predictions.flatten())
gru_mape = calculate_mape(Y_test_eth, gru_predictions.flatten())
bilstm_mape = calculate_mape(Y_test_eth, bilstm_predictions.flatten())

# Print RMSE and MAPE for each model
print(f'LSTM RMSE: {lstm_rmse:.3f}, MAPE: {lstm_mape:.2f}%')
print(f'GRU RMSE: {gru_rmse:.3f}, MAPE: {gru_mape:.2f}%')
print(f'BiLSTM RMSE: {bilstm_rmse:.3f}, MAPE: {bilstm_mape:.2f}%')


#now for  Litecoins all the codes:

from sklearn.preprocessing import MinMaxScaler

# Define the tickers for Bitcoin, Ethereum, and Litecoin
cryptos = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Assuming we're working with Bitcoin data for this example
ltc_data = crypto_data['LTC-USD']

# 1. Handle missing data
# For simplicity, we'll fill missing values with the last available value
ltc_data.fillna(method='ffill', inplace=True)

# 2. Normalize the features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data_ltc = scaler.fit_transform(ltc_data[['Open', 'High', 'Low', 'Close', 'Adj Close']])

# 3. Convert the data into a time series format
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        X.append(a)
        Y.append(dataset[i + look_back, -1]) # Assuming close price is the target variable
    return np.array(X), np.array(Y)

# Define look_back period
look_back = 60 # for example, using past 60 days to predict the next day

# Split into features (X) and target (Y)
X_ltc, Y_ltc = create_dataset(scaled_data_ltc, look_back)

# Reshape features into the format expected by LSTM (samples, time steps, features)
X_ltc = np.reshape(X_ltc, (X_ltc.shape[0], look_back, X_ltc.shape[2]))

# Split into train and test sets
split_percent = 0.80
split = int(split_percent*len(X_ltc))

X_train_ltc = X_ltc[:split]
Y_train_ltc = Y_ltc[:split]
X_test_ltc = X_ltc[split:]
Y_test_ltc = Y_ltc[split:]

print("Data preprocessed and ready for model training.")


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
lstm_model.add(LSTM(units=100))
lstm_model.add(Dense(1))

lstm_model.compile(optimizer='adam', loss='mean_squared_error')


from tensorflow.keras.layers import GRU

# Define the GRU model
gru_model = Sequential()
gru_model.add(GRU(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
gru_model.add(GRU(units=100))
gru_model.add(Dense(1))

gru_model.compile(optimizer='adam', loss='mean_squared_error')


from tensorflow.keras.layers import Bidirectional

# Define the BiLSTM model
bilstm_model = Sequential()
bilstm_model.add(Bidirectional(LSTM(units=100, return_sequences=True), input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
bilstm_model.add(Bidirectional(LSTM(units=100)))
bilstm_model.add(Dense(1))

bilstm_model.compile(optimizer='adam', loss='mean_squared_error')


# Train the LSTM model
lstm_history = lstm_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)

# Train the GRU model
gru_history = gru_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)

# Train the BiLSTM model
bilstm_history = bilstm_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)

# Evaluate the LSTM model
lstm_scores = lstm_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)
print('LSTM Test loss:', lstm_scores)

# Evaluate the GRU model
gru_scores = gru_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)
print('GRU Test loss:', gru_scores)

# Evaluate the BiLSTM model
bilstm_scores = bilstm_model.evaluate(X_test_ltc, Y_test_ltc, verbose=0)
print('BiLSTM Test loss:', bilstm_scores)

plt.figure(figsize=(18,5))
plt.subplot(1,3,1)
plt.plot(lstm_history.history['loss'], label='LSTM training Loss')
plt.plot(lstm_history.history['val_loss'], label='LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,2)
plt.plot(gru_history.history['loss'], label='GRU training Loss')
plt.plot(gru_history.history['val_loss'], label='GRU Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1,3,3)
plt.plot(bilstm_history.history['loss'], label='Bi-LSTM training Loss')
plt.plot(bilstm_history.history['val_loss'], label='Bi-LSTM Validation Loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Make predictions
lstm_predictions = lstm_model.predict(X_test_ltc)
gru_predictions = gru_model.predict(X_test_ltc)
bilstm_predictions = bilstm_model.predict(X_test_ltc)

# Calculate MSE and MAE for LSTM
lstm_mse = mean_squared_error(Y_test_ltc, lstm_predictions)
lstm_mae = mean_absolute_error(Y_test_ltc, lstm_predictions)

# Calculate MSE and MAE for GRU
gru_mse = mean_squared_error(Y_test_ltc, gru_predictions)
gru_mae = mean_absolute_error(Y_test_ltc, gru_predictions)

# Calculate MSE and MAE for BiLSTM
bilstm_mse = mean_squared_error(Y_test_ltc, bilstm_predictions)
bilstm_mae = mean_absolute_error(Y_test_ltc, bilstm_predictions)

# Print the scores
print(f'LSTM MSE: {lstm_mse}, MAE: {lstm_mae}')
print(f'GRU MSE: {gru_mse}, MAE: {gru_mae}')
print(f'BiLSTM MSE: {bilstm_mse}, MAE: {bilstm_mae}')

from tensorflow.keras.optimizers import Adam

# Tune LSTM hyperparameters
tuned_lstm_model = Sequential()
tuned_lstm_model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train_ltc.shape[1], X_train_ltc.shape[2])))
tuned_lstm_model.add(LSTM(units=100))
tuned_lstm_model.add(Dense(1))

# Adjust learning rate
optimizer = Adam(learning_rate=0.001)
tuned_lstm_model.compile(optimizer=optimizer, loss='mean_squared_error')

# Retrain with new hyperparameters
tuned_lstm_history = tuned_lstm_model.fit(X_train_ltc, Y_train_ltc, epochs=100, batch_size=32, validation_data=(X_test_ltc, Y_test_ltc), verbose=1)

# Plot actual vs. predicted prices for the best-performing model (example with LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_ltc, label='Actual Prices')
plt.plot(lstm_predictions, label='Predicted Prices')
plt.title('For LTC Comparison of Actual and LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

# Plot actual vs. predicted prices for the best-performing model (example with GRU)
plt.figure(figsize=(10,6))
plt.plot(Y_test_ltc, label='Actual Prices')
plt.plot(gru_predictions, label='Predicted Prices')
plt.title('For LTC Comparison of Actual and GRU-Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()

# Plot actual vs. predicted prices for the best-performing model (example with Bi-LSTM)
plt.figure(figsize=(10,6))
plt.plot(Y_test_ltc, label='Actual Prices')
plt.plot(bilstm_predictions, label='Predicted Prices')
plt.title('For LTC Comparison of Actual and Bi-LSTM Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Price')
plt.legend()
plt.show()


def calculate_rmse(actuals, predictions):
    """
    Calculate Root Mean Squared Error
    """
    mse = np.mean((actuals - predictions) ** 2)
    rmse = np.sqrt(mse)
    return rmse

def calculate_mape(actuals, predictions):
    """
    Calculate Mean Absolute Percentage Error
    """
    mape = np.mean(np.abs((actuals - predictions) / actuals)) * 100
    return mape

# Assuming Y_test, lstm_predictions, gru_predictions, and bilstm_predictions are already defined

# Calculate RMSE for each model
lstm_rmse = calculate_rmse(Y_test_ltc, lstm_predictions.flatten())
gru_rmse = calculate_rmse(Y_test_ltc, gru_predictions.flatten())
bilstm_rmse = calculate_rmse(Y_test_ltc, bilstm_predictions.flatten())

# Calculate MAPE for each model
lstm_mape = calculate_mape(Y_test_ltc, lstm_predictions.flatten())
gru_mape = calculate_mape(Y_test_ltc, gru_predictions.flatten())
bilstm_mape = calculate_mape(Y_test_ltc, bilstm_predictions.flatten())

# Print RMSE and MAPE for each model
print(f'LSTM RMSE: {lstm_rmse:.3f}, MAPE: {lstm_mape:.2f}%')
print(f'GRU RMSE: {gru_rmse:.3f}, MAPE: {gru_mape:.2f}%')
print(f'BiLSTM RMSE: {bilstm_rmse:.3f}, MAPE: {bilstm_mape:.2f}%')
# Out:
# Requirement already satisfied: yfinance in c:\users\stumpa42\appdata\loca\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\stumpa42\appdata\loca\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\stumpa42\appdata\loca\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Requirement already satisfied: numpy in c:\users\stumpa42\appdata\loca\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\stumpa42\appdata\loca\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\stumpa42\appdata\loca\lib\site-packages (3.7.2)
# Requirement already satisfied: scikit-learn in c:\users\stumpa42\appdata\loca\lib\site-packages (1.3.0)
# Requirement already satisfied: tensorflow in c:\users\stumpa42\appdata\loca\lib\site-packages (2.16.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.38.4)
# Requirement already satisfied: rich in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)
# [*********************100%%**********************]  1 of 1 completed
# Showing data for BTC-USD:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-01-01  3746.713379  3850.913818  3707.231201  3843.520020  3843.520020
# 2019-01-02  3849.216309  3947.981201  3817.409424  3943.409424  3943.409424
# 2019-01-03  3931.048584  3935.685059  3826.222900  3836.741211  3836.741211
# 2019-01-04  3832.040039  3865.934570  3783.853760  3857.717529  3857.717529
# 2019-01-05  3851.973877  3904.903076  3836.900146  3845.194580  3845.194580
#
#                 Volume
# Date
# 2019-01-01  4324200990
# 2019-01-02  5244856836
# 2019-01-03  4530215219
# 2019-01-04  4847965467
# 2019-01-05  5137609824
# [*********************100%%**********************]  1 of 1 completed
# Showing data for ETH-USD:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  133.418152  141.397507  132.650711  140.819412  140.819412
# 2019-01-02  141.519516  156.929138  140.650955  155.047684  155.047684
# 2019-01-03  155.196045  155.863052  147.198364  149.135010  149.135010
# 2019-01-04  148.912888  156.878983  147.907104  154.581940  154.581940
# 2019-01-05  154.337418  160.824890  154.337418  155.638596  155.638596
#
#                 Volume
# Date
# 2019-01-01  2258709868
# 2019-01-02  3328240369
# 2019-01-03  2676164880
# 2019-01-04  3126192535
# 2019-01-05  3338211928
# [*********************100%%**********************]  1 of 1 completed
# Showing data for LTC-USD:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-01  30.458393  32.097584  30.264280  31.979931  31.979931  379429124
# 2019-01-02  32.021229  33.793324  31.765974  33.433681  33.433681  414331918
# 2019-01-03  33.353573  33.420704  31.592480  32.026699  32.026699  345068249
# 2019-01-04  32.016525  33.023350  31.437557  32.404167  32.404167  391010579
# 2019-01-05  32.345547  36.143440  32.344795  34.936867  34.936867  640607603
# Data preprocessed and ready for model training.
# Requirement already satisfied: tensorflow in c:\users\stumpa42\appdata\loca\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.24.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.38.4)
# Requirement already satisfied: rich in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\stumpa42\appdata\loca\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stumpa42\appdata\loca\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\stumpa42\appdata\loca\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\stumpa42\appdata\loca\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)
# C:\Users\stumpa42\AppData\Loca\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# C:\Users\stumpa42\AppData\Loca\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0223 - val_loss: 6.7984e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0018 - val_loss: 6.2163e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0014 - val_loss: 4.8592e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0015 - val_loss: 5.0031e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0011 - val_loss: 3.7301e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 9.8851e-04 - val_loss: 3.8554e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0010 - val_loss: 7.8572e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0010 - val_loss: 4.0702e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 9.4495e-04 - val_loss: 3.0001e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 8.0871e-04 - val_loss: 2.7335e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 8.0490e-04 - val_loss: 4.8042e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 8.2674e-04 - val_loss: 3.6642e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 7.4053e-04 - val_loss: 6.1085e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.1502e-04 - val_loss: 3.2017e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.9150e-04 - val_loss: 2.2381e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 5.8043e-04 - val_loss: 2.3374e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.0891e-04 - val_loss: 2.7583e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 6.1959e-04 - val_loss: 8.2734e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 7.8671e-04 - val_loss: 1.9431e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 5.7842e-04 - val_loss: 1.7475e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 5.6593e-04 - val_loss: 4.6380e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 5.3670e-04 - val_loss: 1.6724e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 6.4890e-04 - val_loss: 3.3189e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 5.3813e-04 - val_loss: 2.8043e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.1864e-04 - val_loss: 4.6834e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - loss: 5.6757e-04 - val_loss: 3.6752e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.3252e-04 - val_loss: 4.2289e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 5.6407e-04 - val_loss: 1.6249e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.2131e-04 - val_loss: 1.4269e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 4.9153e-04 - val_loss: 6.3704e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 6.9563e-04 - val_loss: 1.6048e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.1769e-04 - val_loss: 1.3061e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.1607e-04 - val_loss: 2.4033e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.2076e-04 - val_loss: 1.2619e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 3.7204e-04 - val_loss: 1.5707e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.1876e-04 - val_loss: 2.3195e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.6275e-04 - val_loss: 2.7108e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.9663e-04 - val_loss: 1.1618e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.6408e-04 - val_loss: 1.4358e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.7000e-04 - val_loss: 1.2751e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 3.6468e-04 - val_loss: 4.2436e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.4213e-04 - val_loss: 1.5497e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.7980e-04 - val_loss: 1.1221e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.8786e-04 - val_loss: 3.6427e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.3733e-04 - val_loss: 1.1706e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.6356e-04 - val_loss: 1.0789e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.8652e-04 - val_loss: 3.3684e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 4.4512e-04 - val_loss: 1.7666e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.6645e-04 - val_loss: 1.4811e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.6039e-04 - val_loss: 1.0959e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 3.2517e-04 - val_loss: 1.0675e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 3.5624e-04 - val_loss: 2.9126e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 5.6055e-04 - val_loss: 1.2390e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.1760e-04 - val_loss: 1.1735e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.5946e-04 - val_loss: 1.4018e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.5568e-04 - val_loss: 1.0591e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.6449e-04 - val_loss: 1.3079e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.1662e-04 - val_loss: 2.1722e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.3778e-04 - val_loss: 1.1248e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.2591e-04 - val_loss: 1.0949e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.7312e-04 - val_loss: 1.2999e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.6515e-04 - val_loss: 1.2387e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.8446e-04 - val_loss: 4.0337e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.0100e-04 - val_loss: 1.0467e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.6306e-04 - val_loss: 1.0371e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.4772e-04 - val_loss: 1.1057e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.8638e-04 - val_loss: 0.0021
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0014 - val_loss: 2.4139e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.4645e-04 - val_loss: 1.2406e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.6455e-04 - val_loss: 1.3786e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.8123e-04 - val_loss: 1.1489e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.2334e-04 - val_loss: 1.0477e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.7311e-04 - val_loss: 1.2372e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 3.6006e-04 - val_loss: 1.9037e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.7349e-04 - val_loss: 1.3628e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 3.1899e-04 - val_loss: 1.6720e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.9048e-04 - val_loss: 1.0650e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 3.2960e-04 - val_loss: 1.0340e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.6528e-04 - val_loss: 2.5199e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.8170e-04 - val_loss: 1.5018e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.5020e-04 - val_loss: 2.3807e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.0511e-04 - val_loss: 1.1650e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.1303e-04 - val_loss: 1.7612e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.4194e-04 - val_loss: 1.2739e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.7168e-04 - val_loss: 1.0207e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.2178e-04 - val_loss: 2.3094e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.3031e-04 - val_loss: 2.3467e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.4445e-04 - val_loss: 1.5653e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.5565e-04 - val_loss: 1.2648e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.3008e-04 - val_loss: 1.6261e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.1768e-04 - val_loss: 1.3435e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 3.8246e-04 - val_loss: 1.0206e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.4700e-04 - val_loss: 1.8238e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.8855e-04 - val_loss: 1.1114e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.4069e-04 - val_loss: 2.0432e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.3886e-04 - val_loss: 1.8099e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.6784e-04 - val_loss: 1.0167e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.6652e-04 - val_loss: 4.3364e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.1717e-04 - val_loss: 1.8126e-04
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.0317 - val_loss: 3.9688e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 6.9234e-04 - val_loss: 2.2696e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.2321e-04 - val_loss: 1.8618e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 5.5117e-04 - val_loss: 2.0013e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 5.5037e-04 - val_loss: 1.5029e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.9068e-04 - val_loss: 2.0426e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.2790e-04 - val_loss: 3.1640e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.6334e-04 - val_loss: 2.4960e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.8020e-04 - val_loss: 2.2314e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.2904e-04 - val_loss: 4.3552e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 5.6146e-04 - val_loss: 1.5299e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 3.6133e-04 - val_loss: 3.0544e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.2831e-04 - val_loss: 1.3084e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.8216e-04 - val_loss: 2.5638e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 4.2895e-04 - val_loss: 1.2246e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.7415e-04 - val_loss: 1.0691e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.8361e-04 - val_loss: 1.0860e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.6780e-04 - val_loss: 2.8217e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 5.0458e-04 - val_loss: 1.0788e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.3656e-04 - val_loss: 1.0552e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.2862e-04 - val_loss: 1.1408e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.9338e-04 - val_loss: 1.3322e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.1944e-04 - val_loss: 1.4271e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.4103e-04 - val_loss: 1.6613e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.4020e-04 - val_loss: 1.3457e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.6358e-04 - val_loss: 2.4821e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.2968e-04 - val_loss: 3.5471e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.9891e-04 - val_loss: 7.0258e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.5137e-04 - val_loss: 1.4303e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.0439e-04 - val_loss: 1.2500e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 4.2948e-04 - val_loss: 1.1307e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.9711e-04 - val_loss: 1.0459e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.2428e-04 - val_loss: 1.9655e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.0945e-04 - val_loss: 1.4886e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 3.8191e-04 - val_loss: 1.5756e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.7467e-04 - val_loss: 2.5818e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 5.4483e-04 - val_loss: 5.9732e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.5959e-04 - val_loss: 1.0478e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 3.1730e-04 - val_loss: 2.1779e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.6360e-04 - val_loss: 3.9824e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 5.0560e-04 - val_loss: 1.0241e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.6853e-04 - val_loss: 1.6471e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.5260e-04 - val_loss: 1.0236e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 2.9503e-04 - val_loss: 1.0702e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 3.7110e-04 - val_loss: 1.3515e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.5499e-04 - val_loss: 1.1933e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.7969e-04 - val_loss: 1.5401e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.2495e-04 - val_loss: 1.7287e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.5069e-04 - val_loss: 2.6032e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 3.8614e-04 - val_loss: 1.0470e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.9907e-04 - val_loss: 2.1516e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.5159e-04 - val_loss: 2.4710e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.9366e-04 - val_loss: 3.1797e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.8616e-04 - val_loss: 1.0279e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.6401e-04 - val_loss: 1.0095e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.9080e-04 - val_loss: 1.0306e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 3.5502e-04 - val_loss: 1.0064e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 3.0930e-04 - val_loss: 2.3687e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 4.6193e-04 - val_loss: 1.7033e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 3.5944e-04 - val_loss: 1.0099e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.3915e-04 - val_loss: 1.6886e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 4.7560e-04 - val_loss: 1.0023e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 3.4630e-04 - val_loss: 3.6346e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.7847e-04 - val_loss: 0.0012
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 8.4154e-04 - val_loss: 2.6669e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 8.5228e-04 - val_loss: 1.0498e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 4.0143e-04 - val_loss: 1.6599e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 3.7951e-04 - val_loss: 2.1695e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 4.9415e-04 - val_loss: 2.8510e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 3.7831e-04 - val_loss: 2.7018e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 3.1779e-04 - val_loss: 1.5798e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.0453e-04 - val_loss: 4.2730e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 6.8411e-04 - val_loss: 1.3219e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.5906e-04 - val_loss: 1.4976e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.5740e-04 - val_loss: 1.1992e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 3.9395e-04 - val_loss: 1.0120e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.2212e-04 - val_loss: 1.1717e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.3909e-04 - val_loss: 9.9794e-05
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.0142e-04 - val_loss: 1.0075e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.1471e-04 - val_loss: 2.7816e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.3350e-04 - val_loss: 1.2289e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.3765e-04 - val_loss: 1.0151e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.3796e-04 - val_loss: 1.0670e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 3.6323e-04 - val_loss: 1.0814e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 3.3858e-04 - val_loss: 1.1644e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.7206e-04 - val_loss: 1.4539e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.6209e-04 - val_loss: 1.7213e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 3.7194e-04 - val_loss: 1.0509e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 3.9945e-04 - val_loss: 1.8830e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.2802e-04 - val_loss: 1.2910e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.6451e-04 - val_loss: 9.9344e-05
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 3.8552e-04 - val_loss: 1.9185e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.7051e-04 - val_loss: 1.8440e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.6915e-04 - val_loss: 9.9556e-05
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0041e-04 - val_loss: 3.6569e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 3.6986e-04 - val_loss: 1.0848e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 3.8064e-04 - val_loss: 2.9021e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 3.7479e-04 - val_loss: 1.0142e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.5049e-04 - val_loss: 1.0644e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 3.8650e-04 - val_loss: 1.0292e-04
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - loss: 0.0366 - val_loss: 0.0032
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - loss: 0.0024 - val_loss: 4.2401e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 9.3953e-04 - val_loss: 3.5340e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 0.0011 - val_loss: 2.9546e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 8.3757e-04 - val_loss: 2.7573e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 7.8081e-04 - val_loss: 5.1291e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 7.3734e-04 - val_loss: 3.3027e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 6.2404e-04 - val_loss: 4.9627e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 7.2566e-04 - val_loss: 5.1775e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 6.2949e-04 - val_loss: 2.4847e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 6.1586e-04 - val_loss: 3.4589e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 6.0159e-04 - val_loss: 0.0010
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 7.9975e-04 - val_loss: 7.3305e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 6.0515e-04 - val_loss: 1.8735e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 5.2927e-04 - val_loss: 1.6876e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 5.3016e-04 - val_loss: 0.0014
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 0.0013 - val_loss: 1.7302e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.7423e-04 - val_loss: 2.2330e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - loss: 4.3952e-04 - val_loss: 1.6496e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.6952e-04 - val_loss: 1.5297e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.4925e-04 - val_loss: 6.0363e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - loss: 4.8587e-04 - val_loss: 2.0626e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.8319e-04 - val_loss: 5.7493e-04
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 5.2738e-04 - val_loss: 2.4091e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 5.2025e-04 - val_loss: 1.7978e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 5.5194e-04 - val_loss: 2.9398e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.8055e-04 - val_loss: 1.7726e-04
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.2683e-04 - val_loss: 1.8227e-04
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.9940e-04 - val_loss: 4.5293e-04
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 5.4540e-04 - val_loss: 1.2819e-04
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.8113e-04 - val_loss: 6.4545e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 6.7163e-04 - val_loss: 5.5398e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 4.7957e-04 - val_loss: 6.3340e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 4.7571e-04 - val_loss: 2.3210e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 5.3719e-04 - val_loss: 1.3476e-04
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.4123e-04 - val_loss: 1.6247e-04
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.4798e-04 - val_loss: 1.5302e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.7896e-04 - val_loss: 1.1668e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.7854e-04 - val_loss: 1.5995e-04
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.0356e-04 - val_loss: 1.3042e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 3.5529e-04 - val_loss: 1.4895e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 4.3933e-04 - val_loss: 2.3785e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 6.1475e-04 - val_loss: 1.8768e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.9143e-04 - val_loss: 2.7868e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.5467e-04 - val_loss: 1.1366e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 3.9275e-04 - val_loss: 2.5694e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 4.5229e-04 - val_loss: 6.2841e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 4.3298e-04 - val_loss: 1.8186e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.9411e-04 - val_loss: 1.1045e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.6500e-04 - val_loss: 1.2906e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.4547e-04 - val_loss: 1.0848e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.9514e-04 - val_loss: 1.4467e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.9457e-04 - val_loss: 1.1301e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.7270e-04 - val_loss: 3.2041e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.2025e-04 - val_loss: 1.5389e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.7301e-04 - val_loss: 1.5746e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.2198e-04 - val_loss: 3.1450e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 3.4126e-04 - val_loss: 1.1347e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 2.8628e-04 - val_loss: 3.9821e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.6757e-04 - val_loss: 1.1253e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.5026e-04 - val_loss: 1.1535e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 3.8822e-04 - val_loss: 8.2844e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 5.1166e-04 - val_loss: 1.8924e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.8861e-04 - val_loss: 1.0758e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.4095e-04 - val_loss: 1.4271e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.9237e-04 - val_loss: 3.7517e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.9687e-04 - val_loss: 1.3795e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 3.3244e-04 - val_loss: 2.1087e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.4620e-04 - val_loss: 6.3372e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.5731e-04 - val_loss: 2.1087e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 3.1982e-04 - val_loss: 1.4272e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 91ms/step - loss: 3.4493e-04 - val_loss: 1.2588e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 3.3085e-04 - val_loss: 3.4351e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.0256e-04 - val_loss: 2.9943e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 5.2900e-04 - val_loss: 1.7796e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - loss: 3.6512e-04 - val_loss: 1.3263e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 3.2667e-04 - val_loss: 1.7270e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.6360e-04 - val_loss: 1.3917e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 3.8644e-04 - val_loss: 6.3914e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 4.4085e-04 - val_loss: 9.9972e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 7.3470e-04 - val_loss: 1.0881e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.1828e-04 - val_loss: 1.0798e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.5448e-04 - val_loss: 1.5297e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 2.9989e-04 - val_loss: 1.4137e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - loss: 3.5596e-04 - val_loss: 1.4151e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 3.7261e-04 - val_loss: 1.1136e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - loss: 3.1594e-04 - val_loss: 1.7455e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 97ms/step - loss: 3.0902e-04 - val_loss: 1.3509e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.8291e-04 - val_loss: 1.1195e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - loss: 4.2280e-04 - val_loss: 0.0018
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - loss: 7.5955e-04 - val_loss: 1.1922e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - loss: 4.1080e-04 - val_loss: 3.1215e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - loss: 3.5134e-04 - val_loss: 1.3861e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - loss: 3.5249e-04 - val_loss: 2.3348e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.0696e-04 - val_loss: 1.1400e-04
# Epoch 96/100
# ...
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 94ms/step - loss: 4.9553e-04 - val_loss: 8.2997e-05
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 4.5110e-04 - val_loss: 1.0883e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 4.0441e-04 - val_loss: 1.0478e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.6060e-04 - val_loss: 7.8975e-05
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.8635e-04 - val_loss: 1.0773e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.4253e-04 - val_loss: 1.0172e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.6769e-04 - val_loss: 9.8772e-05
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.9955e-04 - val_loss: 7.4144e-05
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 3.8208e-04 - val_loss: 1.1088e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 5.3073e-04 - val_loss: 8.0112e-05
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.8714e-04 - val_loss: 7.1511e-05
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0651e-04 - val_loss: 7.7623e-05
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 4.1128e-04 - val_loss: 6.9061e-05
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 4.1226e-04 - val_loss: 1.0781e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 5.2162e-04 - val_loss: 9.0889e-05
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.5785e-04 - val_loss: 9.4130e-05
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - loss: 3.8137e-04 - val_loss: 9.0321e-05
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 5.4340e-04 - val_loss: 7.6290e-05
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.8894e-04 - val_loss: 1.7481e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 5.3225e-04 - val_loss: 1.5712e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.5742e-04 - val_loss: 8.9504e-05
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.3635e-04 - val_loss: 7.3856e-05
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 3.8287e-04 - val_loss: 7.1717e-05
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 4.6092e-04 - val_loss: 1.2623e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.0497e-04 - val_loss: 8.6202e-05
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 5.5192e-04 - val_loss: 2.9859e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 6.3125e-04 - val_loss: 6.7532e-05
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0739e-04 - val_loss: 6.6871e-05
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.8174e-04 - val_loss: 7.1007e-05
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 4.3116e-04 - val_loss: 1.7349e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 6.8228e-04 - val_loss: 7.0813e-05
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.9409e-04 - val_loss: 8.1065e-05
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 5.3290e-04 - val_loss: 1.5845e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - loss: 5.6762e-04 - val_loss: 7.3009e-05
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 3.9558e-04 - val_loss: 1.4231e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.9224e-04 - val_loss: 9.5533e-05
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.5745e-04 - val_loss: 8.2130e-05
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.2010e-04 - val_loss: 8.1627e-05
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 4.1137e-04 - val_loss: 7.1819e-05
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 4.1769e-04 - val_loss: 6.8547e-05
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 4.8202e-04 - val_loss: 6.6899e-05
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 4.9091e-04 - val_loss: 2.0372e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 5.8856e-04 - val_loss: 8.5345e-05
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 5.4074e-04 - val_loss: 1.2742e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.9873e-04 - val_loss: 6.5279e-05
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 3.8938e-04 - val_loss: 7.3945e-05
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 4.1108e-04 - val_loss: 7.8992e-05
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 5.4864e-04 - val_loss: 7.4464e-05
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 4.0883e-04 - val_loss: 1.0591e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.1435e-04 - val_loss: 6.3259e-05
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 5.0612e-04 - val_loss: 8.9893e-05
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 3.8776e-04 - val_loss: 7.1365e-05
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.8130e-04 - val_loss: 8.7510e-05
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 90ms/step - loss: 4.9455e-04 - val_loss: 7.0792e-05
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 3.7537e-04 - val_loss: 6.7954e-05
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.2741e-04 - val_loss: 6.5847e-05
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.1655e-04 - val_loss: 1.2918e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 5.2588e-04 - val_loss: 6.2150e-05
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 6.3650e-04 - val_loss: 7.9125e-05
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.8049e-04 - val_loss: 6.2581e-05
# LSTM Test loss: 6.212681910255924e-05
# GRU Test loss: 0.00010800800373544917
# BiLSTM Test loss: 6.25805914751254e-05
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step
# LSTM MSE: 6.735540827588208e-05, MAE: 0.005397877529710795
# GRU MSE: 0.00011509651715170854, MAE: 0.008055498736493655
# BiLSTM MSE: 6.755777028522759e-05, MAE: 0.005422315886698872
# Epoch 1/100
# C:\Users\stumpa42\AppData\Loca\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0141 - val_loss: 2.2004e-04
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0020 - val_loss: 2.8138e-04
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0015 - val_loss: 2.7962e-04
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0012 - val_loss: 2.6464e-04
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0013 - val_loss: 1.5760e-04
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 8.5698e-04 - val_loss: 2.4729e-04
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 9.3350e-04 - val_loss: 1.3715e-04
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.9398e-04 - val_loss: 1.3143e-04
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 6.4621e-04 - val_loss: 1.2857e-04
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 7.6245e-04 - val_loss: 1.3078e-04
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 6.7419e-04 - val_loss: 1.2418e-04
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0010 - val_loss: 1.5494e-04
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 8.0123e-04 - val_loss: 1.6999e-04
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 6.4351e-04 - val_loss: 1.3718e-04
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.5635e-04 - val_loss: 1.2390e-04
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 5.8830e-04 - val_loss: 2.5608e-04
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 6.6213e-04 - val_loss: 1.0596e-04
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 6.4314e-04 - val_loss: 2.1363e-04
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 5.8265e-04 - val_loss: 1.3283e-04
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 5.4208e-04 - val_loss: 2.6269e-04
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 7.4585e-04 - val_loss: 1.0320e-04
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 4.7209e-04 - val_loss: 1.2613e-04
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 6.5755e-04 - val_loss: 9.6812e-05
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 6.8354e-04 - val_loss: 1.0247e-04
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 5.4912e-04 - val_loss: 2.7459e-04
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.7940e-04 - val_loss: 1.0746e-04
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.6637e-04 - val_loss: 8.9942e-05
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.8177e-04 - val_loss: 8.9063e-05
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.7352e-04 - val_loss: 8.9814e-05
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 6.0077e-04 - val_loss: 8.7927e-05
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.7467e-04 - val_loss: 3.3060e-04
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 8.0570e-04 - val_loss: 1.5766e-04
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.3367e-04 - val_loss: 1.6179e-04
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 6.0754e-04 - val_loss: 1.0837e-04
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 7.2175e-04 - val_loss: 8.8909e-05
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.2093e-04 - val_loss: 8.4668e-05
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.6913e-04 - val_loss: 1.7959e-04
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 6.4925e-04 - val_loss: 1.3774e-04
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 5.7741e-04 - val_loss: 7.9335e-05
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.3147e-04 - val_loss: 1.8178e-04
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.9100e-04 - val_loss: 2.2715e-04
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.7858e-04 - val_loss: 2.1907e-04
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 7.1627e-04 - val_loss: 1.2057e-04
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 6.0886e-04 - val_loss: 1.5911e-04
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 7.0822e-04 - val_loss: 2.7082e-04
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 6.4385e-04 - val_loss: 9.3818e-05
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 5.2142e-04 - val_loss: 1.2515e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.7461e-04 - val_loss: 9.3870e-05
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.9219e-04 - val_loss: 1.2297e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.1752e-04 - val_loss: 7.6367e-05
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.2918e-04 - val_loss: 9.7142e-05
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 4.5304e-04 - val_loss: 9.0522e-05
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.4111e-04 - val_loss: 8.2022e-05
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 6.3409e-04 - val_loss: 7.6147e-05
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.9882e-04 - val_loss: 1.0372e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.4205e-04 - val_loss: 8.5650e-05
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.0633e-04 - val_loss: 8.0273e-05
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 6.0470e-04 - val_loss: 8.0133e-05
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 5.3065e-04 - val_loss: 8.3169e-05
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 5.5959e-04 - val_loss: 7.5619e-05
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.3179e-04 - val_loss: 8.0722e-05
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.9005e-04 - val_loss: 8.4247e-05
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.8408e-04 - val_loss: 1.0765e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 3.6870e-04 - val_loss: 1.0268e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.1231e-04 - val_loss: 8.5472e-05
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.0967e-04 - val_loss: 7.3409e-05
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 3.9208e-04 - val_loss: 7.0250e-05
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.0362e-04 - val_loss: 1.1030e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 4.5656e-04 - val_loss: 7.1302e-05
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 5.4392e-04 - val_loss: 1.3260e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 6.4534e-04 - val_loss: 2.5463e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.5769e-04 - val_loss: 1.2553e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.4452e-04 - val_loss: 7.7673e-05
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.7728e-04 - val_loss: 1.6928e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.0821e-04 - val_loss: 1.3346e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.2996e-04 - val_loss: 9.3575e-05
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.7909e-04 - val_loss: 9.6032e-05
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.1591e-04 - val_loss: 6.8454e-05
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.2644e-04 - val_loss: 8.8087e-05
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.3859e-04 - val_loss: 6.6050e-05
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.2957e-04 - val_loss: 1.1008e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.1357e-04 - val_loss: 6.6743e-05
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.9235e-04 - val_loss: 8.5291e-05
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 3.6625e-04 - val_loss: 6.4796e-05
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 3.7404e-04 - val_loss: 7.2211e-05
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.9030e-04 - val_loss: 1.7865e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 7.4043e-04 - val_loss: 1.0074e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.0684e-04 - val_loss: 7.3654e-05
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.4989e-04 - val_loss: 7.9240e-05
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 4.5493e-04 - val_loss: 1.0182e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 4.9926e-04 - val_loss: 7.2827e-05
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 3.9000e-04 - val_loss: 6.6970e-05
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 4.4718e-04 - val_loss: 1.1539e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 4.4339e-04 - val_loss: 1.1078e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.4122e-04 - val_loss: 6.7286e-05
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 3.5216e-04 - val_loss: 9.9473e-05
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 3.7717e-04 - val_loss: 6.9398e-05
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 5.0391e-04 - val_loss: 8.3520e-05
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 4.2801e-04 - val_loss: 6.4775e-05
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.8090e-04 - val_loss: 2.7804e-04
# LSTM RMSE: 0.008, MAPE: 3.75%
# GRU RMSE: 0.011, MAPE: 5.67%
# BiLSTM RMSE: 0.008, MAPE: 3.82%
